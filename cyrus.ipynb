# %% [markdown]
# # 1.Business Understanding
#
# ## Context and Rationale
#
# #### In an increasingly interconnected world, the emergence of global health crises, such as pandemics, poses a significant threat to public health, economies, and societies. Traditional healthcare systems primarily focus on reactive, retrospective analyses of health data, often relying on past outbreak information to manage future risks. While this approach provides valuable insights, it falls short in offering proactive solutions, delaying timely intervention and response when outbreaks begin to escalate.
#
# #### This project is driven by the urgent need to shift from retrospective healthcare analytics to preemptive, predictive models that can forecast potential disease outbreaks before they spiral out of control. By harnessing the power of machine learning and advanced data analytics, our goal is to build an early warning system capable of identifying emerging health threats with enough lead time to enable swift, targeted intervention. This shift not only improves global pandemic preparedness but also contributes to the achievement of key United Nations Sustainable Development Goals (SDGs) that focus on health, infrastructure, and collaboration across global systems.
#
# ## Business Problem
#
# #### Current global health surveillance systems are largely reactive and insufficiently equipped to anticipate the rise of potential outbreaks. These systems tend to focus on historical data and post-outbreak analysis, which leads to a delayed response in terms of containment and intervention. The lack of real-time predictive capabilities results in unnecessary loss of life, overwhelming healthcare infrastructures, and severe economic disruptions. A proactive, predictive approach to outbreak management is crucial for improving health system resilience, safeguarding public health, and minimizing the broader social and economic impact of disease outbreaks.
#
# ## Opportunity
#
# #### Our project addresses this gap by developing a machine learning-driven early warning system that leverages historical health data and real-time monitoring to predict disease outbreaks with higher accuracy and lead time. By combining time-series forecasting, anomaly detection, and geospatial clustering techniques, we aim to generate actionable insights that will inform decision-making processes at the global, national, and regional levels. This system will not only aid in early detection but will also provide risk scores for high-risk regions, allowing policymakers and emergency response teams to take timely and informed actions to prevent or mitigate the impact of outbreaks.
#
# ## Strategic Value
#
# #### The development of an early warning system for disease outbreaks holds immense strategic value, particularly for enhancing global health resilience, especially in regions with limited resources. The key benefits of this initiative include:
# #### •	Proactive Threat Identification: By detecting emerging health threats early, we can significantly reduce mortality rates, limit the spread of diseases, and prevent overwhelming healthcare systems.
# #### •	Economic Protection: Early detection will help avoid economic downturns caused by widespread health crises, ensuring that industries, communities, and economies can continue functioning during outbreaks.
# #### •	Alignment with United Nations Sustainable Development Goals (SDGs): This initiative directly supports the achievement of several SDGs, including:
# #### o	SDG 3 (Good Health and Well-Being): By preventing and controlling disease outbreaks, we contribute to better health outcomes globally.
# #### o	SDG 9 (Industry, Innovation, and Infrastructure): Promoting technological innovation in health infrastructure.
# #### o	SDG 13 (Climate Action): Addressing health impacts of climate change by detecting diseases potentially linked to environmental changes.
# #### o	SDG 17 (Partnerships for the Goals): Collaborating globally to tackle shared health challenges and strengthen international partnerships.
# #### •	Empowering Global Health Organizations: By providing a data-driven framework for early disease outbreak detection, the project equips global health organizations, governments, and emergency response teams with essential tools to:
# #### o	Save lives by acting swiftly.
# #### o	Optimize resource allocation during health crises.
# #### o	Respond more effectively and efficiently to outbreaks.
# #### This initiative not only strengthens health systems globally but also fosters greater collaboration in achieving sustainable health and development goals.

# %% [markdown]
# # 2.Data Understanding
#
# **About the Dataset:**
#
# #### This dataset offers a detailed collection of global health statistics, focusing on a wide range of diseases, treatments, and health outcomes across multiple countries and years. It provides a valuable resource for health researchers, epidemiologists, and data scientists, offering insights into the prevalence, incidence, and mortality rates of various diseases. Additionally, it highlights the effectiveness of treatments and the state of healthcare infrastructure, making it suitable for various analytical applications, including public health studies, policy development, and machine learning tasks.It has been sourced from kaggle(https://www.kaggle.com/datasets/malaiarasugraj/global-health-statistics?)
#
# **Potential Use Cases:**
#
# #### This dataset can be applied in various areas, including but not limited to:
#
# - **Healthcare Policy Analysis**: Identifying disease trends and determining areas where healthcare investments are most needed to improve infrastructure and services.
#
# - **Epidemiological Studies**: Examining the relationship between disease patterns and socio-economic factors such as income, education, and urbanization.
#
# - **Machine Learning Applications**: Leveraging historical data to build predictive models that forecast disease trends, treatment efficacy, and mortality rates.
#
# - **Global Health Research**: Pinpointing regions or populations in need of specific interventions, targeted health campaigns, or public health strategies.
#
# **Expected Update Frequency:** Annually
#
# **Column Descriptions:**
#
# - **Country**: The country where the health data was recorded.
# - **Year**: The year the data was collected.
# - **Disease Name**: The name of the disease or health condition being tracked.
# - **Disease Category**: The classification of the disease (e.g., Infectious, Non-Communicable, Chronic).
# - **Prevalence Rate (%)**: The percentage of the population affected by the disease.
# - **Incidence Rate (%)**: The percentage of newly diagnosed cases or new instances of the disease.
# - **Mortality Rate (%)**: The percentage of the affected population that dies as a result of the disease.
# - **Age Group**: The age range most affected by the disease.
# - **Gender**: The gender(s) predominantly affected by the disease (Male, Female, Both)
# - **Population Affected**: The total number of individuals affected by the disease.
# - **Healthcare Access (%)**: The percentage of the population with access to healthcare.
# - **Doctors per 1000**: The number of doctors per 1000 people.
# - **Hospital Beds per 1000**: The number of hospital beds available per 1000 people.
# - **Treatment Type**: The primary treatment method for the disease (e.g., Medication, Surgery).
# - **Average Treatment Cost (USD)**: The average cost of treating the disease in USD.
# - **Availability of Vaccines/Treatment**: Whether vaccines or treatments are available.
# - **Recovery Rate (%)**: The percentage of people who recover from the disease.
# - **DALYs**: Disability-Adjusted Life Years, a measure of disease burden.
# - **Improvement in 5 Years (%)**: The improvement in disease outcomes over the last five years.
# - **Per Capita Income (USD)**: The average income per person in the country.
# - **Education Index**: The average level of education in the country.
# - **Urbanization Rate (%)**: The percentage of the population living in urban areas.

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
#Loading the data
df_health = pd.read_csv('Global_Health_Statistics.zip')
df_health.head()
# Out:
#      Country  Year         Disease Name Disease Category  Prevalence Rate (%)  \
# 0      Italy  2013              Malaria      Respiratory                 0.95
# 1     France  2002                Ebola        Parasitic                12.46
# 2     Turkey  2015             COVID-19          Genetic                 0.91
# 3  Indonesia  2011  Parkinson's Disease       Autoimmune                 4.68
# 4      Italy  2013         Tuberculosis          Genetic                 0.83
#
#    Incidence Rate (%)  Mortality Rate (%) Age Group Gender  \
# 0                1.55                8.42      0-18   Male
# 1                8.63                8.75       61+   Male
# 2                2.35                6.22     36-60   Male
# 3                6.29                3.99      0-18  Other
# 4               13.59                7.01       61+   Male
#
#    Population Affected  Healthcare Access (%)  Doctors per 1000  \
# 0               471007                  57.74              3.34
# ...

# %%
#Identifying the coulmns and their data types
df_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   Country                             1000000 non-null  object
#  1   Year                                1000000 non-null  int64
#  2   Disease Name                        1000000 non-null  object
#  3   Disease Category                    1000000 non-null  object
#  4   Prevalence Rate (%)                 1000000 non-null  float64
#  5   Incidence Rate (%)                  1000000 non-null  float64
#  6   Mortality Rate (%)                  1000000 non-null  float64
#  7   Age Group                           1000000 non-null  object
#  8   Gender                              1000000 non-null  object
#  9   Population Affected                 1000000 non-null  int64
# ...

# %%
#Check for missing data
df_health.isna().sum()
# Out:
# Country                               0
# Year                                  0
# Disease Name                          0
# Disease Category                      0
# Prevalence Rate (%)                   0
# Incidence Rate (%)                    0
# Mortality Rate (%)                    0
# Age Group                             0
# Gender                                0
# Population Affected                   0
# Healthcare Access (%)                 0
# Doctors per 1000                      0
# Hospital Beds per 1000                0
# Treatment Type                        0
# Average Treatment Cost (USD)          0
# Availability of Vaccines/Treatment    0
# Recovery Rate (%)                     0
# DALYs                                 0
# Improvement in 5 Years (%)            0
# Per Capita Income (USD)               0
# Education Index                       0
# Urbanization Rate (%)                 0
# dtype: int64

# %%
#To check for duplicates
df_health.duplicated().sum()
# Out:
# 0

# %%
#Descriptive statistics
df_health.describe()
# Out:
#                  Year  Prevalence Rate (%)  Incidence Rate (%)  \
# count  1000000.000000       1000000.000000      1000000.000000
# mean      2011.996999            10.047992            7.555005
# std          7.217287             5.740189            4.298947
# min       2000.000000             0.100000            0.100000
# 25%       2006.000000             5.090000            3.840000
# 50%       2012.000000            10.040000            7.550000
# 75%       2018.000000            15.010000           11.280000
# max       2024.000000            20.000000           15.000000
#
#        Mortality Rate (%)  Population Affected  Healthcare Access (%)  \
# count      1000000.000000       1000000.000000         1000000.000000
# mean             5.049919        500735.427363              74.987835
# std              2.859427        288660.116648              14.436345
# min              0.100000          1000.000000              50.000000
# ...

# %%
#Using a heatmap to understand correlations between numerical features
corr_matrix = df_health.corr()
plt.figure(figsize=(16,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm');

# %%
sample_df_health = df_health.sample(n=100000, random_state = 42)
